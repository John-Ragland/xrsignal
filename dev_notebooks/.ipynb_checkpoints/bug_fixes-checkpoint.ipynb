# %% [markdown]
# # Bug fixes

# %%
import xarray as xr
import numpy as np
import ODLintake
from xrsignal import xrsignal
import OOI_hydrophone_cloud.utils as cloud_utils
import pandas as pd
from dask.distributed import Client

# %load_ext autoreload
# %autoreload 2

# %%
client = Client()

# %%
hdata = ODLintake.open_ooi_lfhydrophones()
hdata_slice = cloud_utils.slice_ds(hdata, pd.Timestamp('2018-01-01'), pd.Timestamp('2018-01-02'), include_coord=False)
hdata_slice
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 17280000)
# Dimensions without coordinates: time
# Data variables:
#     AXBA1    (time) float64 dask.array<chunksize=(720000,), meta=np.ndarray>
#     AXCC1    (time) float64 dask.array<chunksize=(720000,), meta=np.ndarray>
#     AXEC2    (time) float64 dask.array<chunksize=(720000,), meta=np.ndarray>
#     HYS14    (time) float64 dask.array<chunksize=(720000,), meta=np.ndarray>
#     HYSB1    (time) float64 dask.array<chunksize=(720000,), meta=np.ndarray>
# Attributes:
#     channel:        HDH
#     delta:          0.005
#     network:        OO
#     sampling_rate:  200
#     units:          Pa

# %%
spec = xrsignal.welch(1e6*hdata_slice, dim='time', return_onesided=False, dB=True, fs=200).compute()

# %%
spec['HYSB1'].plot()
